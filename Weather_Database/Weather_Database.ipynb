# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
import matplotlib.pyplot as plt
import numpy as np
import requests
import random
from datetime import datetime
from citipy import citipy

# Import the API key.
from config import weather_api_key

# %% [markdown]
# #### Create a new set of 2,000 random latitudes and longitudes.

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes

# %%
def longitudes(size):
    longitudes = []
    x = 0
    while x < (size):
        random_long = random.randint(-180, 180) + random.random()
        longitudes.append(random_long)
        x += 1
    return longitudes

# %%
mylatitudes = latitudes(2000)

# %%
mylongitudes = longitudes(2000)

# %%
coordinates = zip(mylatitudes, mylongitudes)

# %% [markdown]
# #### Get the nearest city using the citipy module.

# %%
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 781

# %%
cities
# Out:
# ['rikitea',
#  'saskylakh',
#  'avera',
#  'mataura',
#  'dikson',
#  'port alfred',
#  'tuktoyaktuk',
#  'port elizabeth',
#  'whitehorse',
#  'college',
#  'fujishiro',
#  'punta arenas',
#  'waipawa',
#  'puerto del rosario',
#  'libacao',
#  'nizhneyansk',
#  'nouadhibou',
#  'craig',
#  'havre-saint-pierre',
#  'albany',
#  'vardo',
#  'samusu',
#  'tsuruga',
#  'busselton',
#  'dahuk',
#  'cape town',
#  'hobart',
#  'maneadero',
#  'leningradskiy',
#  'ilulissat',
#  'sooke',
#  'provideniya',
#  'makakilo city',
#  'westport',
#  'barentsburg',
#  'kieta',
#  'ustye',
#  'jalu',
#  'tabou',
#  'severo-kurilsk',
#  'amapa',
#  'cidreira',
#  'jamestown',
#  'vaitupu',
#  'hilo',
#  'kaitangata',
#  'staryy nadym',
#  'alice springs',
#  'vaini',
#  'olinda',
#  'tuatapere',
#  'yellowknife',
#  'khorramabad',
#  'hermanus',
#  'thompson',
#  'mahibadhoo',
#  'arraial do cabo',
#  'maragogi',
#  'kapaa',
#  'lebu',
#  'iwaki',
#  'taolanaro',
#  'hovd',
#  'belle fourche',
#  'tokur',
#  'el tigre',
#  'panguna',
#  'barrow',
#  'atuona',
#  'ljungby',
#  'masvingo',
#  'touros',
#  'cayenne',
#  'ouesso',
#  'arlit',
#  'bintulu',
#  'puerto ayora',
#  'dickinson',
#  'coronel mariduena',
#  'stornoway',
#  'atar',
#  'georgetown',
#  'anuradhapura',
#  'skagastrond',
#  'ushuaia',
#  'caconda',
#  'sept-iles',
#  'butaritari',
#  'lamar',
#  'japura',
#  'hunza',
#  'alofi',
#  'malaya serdoba',
#  'skibbereen',
#  'lazaro cardenas',
#  'nikolskoye',
#  'bluff',
#  'carbonia',
#  'synya',
#  'ratnagiri',
#  'nagua',
#  'biak',
#  'castro',
#  'lata',
#  'otane',
#  'zhigansk',
#  'monterey',
#  'lavrentiya',
#  'qaanaaq',
#  'kodiak',
#  'casino',
#  'half moon bay',
#  'ponta do sol',
#  'belushya guba',
#  'saint george',
#  'kijabe',
#  'sabang',
#  'san rafael',
#  'grindavik',
#  'bandarbeyla',
#  'caravelas',
#  'upernavik',
#  'san-pedro',
#  'black river',
#  'puerto escondido',
#  'chokurdakh',
#  'laguna',
#  'nanortalik',
#  'lamu',
#  'tres arroyos',
#  'tsihombe',
#  'tiksi',
#  'tommot',
#  'belmonte',
#  'illoqqortoormiut',
#  'muros',
#  'lircay',
#  'tabalosos',
#  'husavik',
#  'san quintin',
#  'sayat',
#  'mar del plata',
#  'cabo san lucas',
#  'tasiilaq',
#  'zemetchino',
#  'bredasdorp',
#  'zhoucheng',
#  'bulgan',
#  'sindor',
#  'esperance',
#  'katherine',
#  'mys shmidta',
#  'busembatia',
#  'rumuruti',
#  'ust-omchug',
#  'grand-lahou',
#  'bontang',
#  'seoul',
#  'hithadhoo',
#  'roma',
#  'pacific grove',
#  'taseyevo',
#  'saint-philippe',
#  'sentyabrskiy',
#  'hirado',
#  'prince rupert',
#  'saint-joseph',
#  'emba',
#  'kaeo',
#  'mitu',
#  'new norfolk',
#  'mangai',
#  'faanui',
#  'roswell',
#  'turukhansk',
#  'bhimunipatnam',
#  'pisco',
#  'ishigaki',
#  'iqaluit',
#  'mezofalva',
#  'bubaque',
#  'souillac',
#  'bengkulu',
#  'imamoglu',
#  'linxia',
#  'moron',
#  'gigmoto',
#  'kavaratti',
#  'lake havasu city',
#  'igarka',
#  'eston',
#  'udachnyy',
#  'yulara',
#  'bisho',
#  'guerrero negro',
#  'nome',
#  'cherskiy',
#  'san cristobal',
#  'terme',
#  'tinskoy',
#  'cururupu',
#  'les cayes',
#  'palabuhanratu',
#  'bang mun nak',
#  'hit',
#  'cruz alta',
#  'nijmegen',
#  'broome',
#  'fairbanks',
#  'chipinge',
#  'sungairaya',
#  'luoyang',
#  'ostrovnoy',
#  'mineiros',
#  'mizdah',
#  'adrar',
#  'ambilobe',
#  'san nicolas',
#  'bethel',
#  'quatre cocos',
#  'khatanga',
#  'afmadu',
#  'belyy yar',
#  'lower hutt',
#  'turan',
#  'christchurch',
#  'ostersund',
#  'tamasane',
#  'mabaruma',
#  'marrakesh',
#  'sitka',
#  'codrington',
#  'grand river south east',
#  'riyadh',
#  'adra',
#  'salinopolis',
#  'faya',
#  'mount gambier',
#  'shadrinsk',
#  'aleksandrov gay',
#  'mouila',
#  'pundaguitan',
#  'gouyave',
#  'sahrak',
#  'vaitape',
#  'chabahar',
#  'umzimvubu',
#  'santiago del estero',
#  'angoche',
#  'hualmay',
#  'san carlos de bariloche',
#  'chuy',
#  'buala',
#  'hammerfest',
#  'broken hill',
#  'kahului',
#  'sao joao da barra',
#  'talcahuano',
#  'santiago',
#  'ahipara',
#  'tumannyy',
#  'sinjai',
#  'padang',
#  'labuhan',
#  'ribeira grande',
#  'avarua',
#  'rudnaya pristan',
#  'torbay',
#  'klaksvik',
#  'lompoc',
#  'komsomolskiy',
#  'kruisfontein',
#  'the valley',
#  'inhambane',
#  'mount isa',
#  'chokwe',
#  'wanaka',
#  'cap malheureux',
#  'taoudenni',
#  'camacha',
#  'werda',
#  'thunder bay',
#  'east london',
#  'ushtobe',
#  'saldanha',
#  'sarankhola',
#  'venice',
#  'byron bay',
#  'airai',
#  'harper',
#  'yumen',
#  'vila velha',
#  'calabar',
#  'luderitz',
#  'santa catarina de tepehuanes',
#  'chatellerault',
#  'savannakhet',
#  'vestmannaeyjar',
#  'ust-nera',
#  'bereda',
#  'shingu',
#  'olafsvik',
#  'lagoa',
#  'moree',
#  'staraya mayna',
#  'hobyo',
#  'suez',
#  'bolungarvik',
#  'narsaq',
#  'borama',
#  'sao filipe',
#  'port hardy',
#  'mugumu',
#  'dunedin',
#  'makurdi',
#  'sayyan',
#  'ancud',
#  'san juan',
#  'sembe',
#  'cartagena del chaira',
#  'ixtapa',
#  'manggar',
#  'karasjok',
#  'sakakah',
#  'shimoda',
#  'aldan',
#  'telford',
#  'boende',
#  'aden',
#  'carnarvon',
#  'belaya gora',
#  'korla',
#  'zanjan',
#  'dabat',
#  'tautira',
#  'cam ranh',
#  'victoria',
#  'mogadishu',
#  'kang',
#  'saint-louis',
#  'wilkie',
#  'muroto',
#  'kenora',
#  'masallatah',
#  'tabory',
#  'sola',
#  'geraldton',
#  'qinhuangdao',
#  'teknaf',
#  'clovis',
#  'warqla',
#  'frutal',
#  'acarau',
#  'cheuskiny',
#  'attawapiskat',
#  'segou',
#  'vysotsk',
#  'rocky mountain house',
#  'bairiki',
#  'lethem',
#  'asfi',
#  'gongzhuling',
#  'karaul',
#  'libertador general san martin',
#  'livingston',
#  'garissa',
#  'constitucion',
#  'mrirt',
#  'graaff-reinet',
#  'russell',
#  'cleethorpes',
#  'centralia',
#  'coquimbo',
#  'mopipi',
#  'cairns',
#  'xichang',
#  'mayo',
#  'akyab',
#  'agropoli',
#  'rocha',
#  'talisayan',
#  'klimovo',
#  'monrovia',
#  'kaniama',
#  'moose factory',
#  'fort dodge',
#  'pevek',
#  'uglegorsk',
#  'lorengau',
#  'dali',
#  'nelson bay',
#  'port lincoln',
#  'sorland',
#  'port moresby',
#  'katsuura',
#  'athens',
#  'burica',
#  'ngukurr',
#  'mehamn',
#  'oranmore',
#  'kurilsk',
#  'deputatskiy',
#  'banmo',
#  'itarema',
#  'neiafu',
#  'dawson creek',
#  'arraias',
#  'chiredzi',
#  'hamilton',
#  'longyearbyen',
#  'gravelbourg',
#  'le mans',
#  'starobaltachevo',
#  'katangli',
#  'port said',
#  'lasa',
#  'goderich',
#  'qianjiang',
#  'elmira',
#  'hendek',
#  'quelimane',
#  'toliary',
#  'doctor pedro p. pena',
#  'lebanon',
#  'warmbad',
#  'wuwei',
#  'lima',
#  'luwuk',
#  'totma',
#  'kasongo-lunda',
#  'keti bandar',
#  'sorvag',
#  'sartell',
#  'kiunga',
#  'namibe',
#  'atakpame',
#  'mahebourg',
#  'vostok',
#  'charlestown',
#  'kushima',
#  'taltal',
#  'loa janan',
#  'qasigiannguit',
#  'cojumatlan',
#  'kutum',
#  'tigre',
#  'necochea',
#  'bukoba',
#  'saint-pierre',
#  'teluknaga',
#  'haines junction',
#  'nuuk',
#  'urumqi',
#  'cottbus',
#  'korgen',
#  'sobolevo',
#  'zyryanka',
#  'langres',
#  'bumbuna',
#  'port blair',
#  'dingle',
#  'ternate',
#  'mitsamiouli',
#  'kamenskoye',
#  'sochi',
#  'puerto leguizamo',
#  'sechura',
#  'houma',
#  'svirstroy',
#  'flinders',
#  'porto novo',
#  'skelleftea',
#  'pahrump',
#  'bambari',
#  'nara',
#  'muravlenko',
#  'inuvik',
#  'pemangkat',
#  'tamale',
#  'sechenovo',
#  'atbasar',
#  'cosala',
#  'jawa',
#  'ucluelet',
#  'wulanhaote',
#  'marcona',
#  'rock sound',
#  'adre',
#  'sharan',
#  'huitzuco',
#  'madimba',
#  'kabanjahe',
#  'phangnga',
#  'baruun-urt',
#  'cochrane',
#  'mananjary',
#  'englewood',
#  'salalah',
#  'tefe',
#  'nichinan',
#  'umm kaddadah',
#  'san patricio',
#  'chunoyar',
#  'santa rita',
#  'prabumulih',
#  'nemuro',
#  'hoquiam',
#  'letka',
#  'puliyankudi',
#  'venado tuerto',
#  'tibiri',
#  'kashi',
#  'motygino',
#  'mana',
#  'aneho',
#  'pangkalanbuun',
#  'hami',
#  'kamloops',
#  'innisfail',
#  'marawi',
#  'amderma',
#  'namatanai',
#  'gidam',
#  'kankon',
#  'marzuq',
#  'santa lucia',
#  'gopalganj',
#  'morros',
#  'khani',
#  'praia',
#  'sungaipenuh',
#  'isangel',
#  'candawaga',
#  'manyana',
#  'ginda',
#  'abhar',
#  'raduzhnyy',
#  'bolonchen',
#  'simplicio mendes',
#  'asmar',
#  'champerico',
#  'san felipe',
#  'kavieng',
#  'beni mazar',
#  'beira',
#  'ondjiva',
#  'bulaevo',
#  'salair',
#  'larsnes',
#  'zabol',
#  'trairi',
#  'kamennomostskiy',
#  'springville',
#  'meyungs',
#  'siva',
#  'machico',
#  'lipari',
#  'wattegama',
#  'chernyakhiv',
#  'grand gaube',
#  'boyolangu',
#  'mastic beach',
#  'gurgan',
#  'marks',
#  'odweyne',
#  'aklavik',
#  'hope',
#  'kiama',
#  'huntsville',
#  'ulladulla',
#  'asau',
#  'sao miguel do araguaia',
#  'mirnyy',
#  'los banos',
#  'ulaangom',
#  'oranjemund',
#  'pangnirtung',
#  'le port',
#  'pyaozerskiy',
#  'sena madureira',
#  'martil',
#  'dzhida',
#  'dolbeau',
#  'clyde river',
#  'tamandare',
#  'ercis',
#  'rungata',
#  'poum',
#  'tilichiki',
#  'yining',
#  'nakamura',
#  'sao francisco',
#  'egvekinot',
#  'dukat',
#  'tagusao',
#  'moengo',
#  'sao felix do xingu',
#  'lerwick',
#  'bonthe',
#  'raton',
#  'senmonorom',
#  'vao',
#  'batesville',
#  'wajir',
#  'miraflores',
#  'hasaki',
#  'talnakh',
#  'north bend',
#  'qaqortoq',
#  'manta',
#  'khilok',
#  'tabukiniberu',
#  'myitkyina',
#  'rio gallegos',
#  'serrinha',
#  'tawzar',
#  'verkhnyaya inta',
#  'santa rosa',
#  'sigli',
#  'ritchie',
#  'vanimo',
#  'castelo branco',
#  'moranbah',
#  'palmer',
#  'plettenberg bay',
#  'suruc',
#  'vilhena',
#  'maceio',
#  'aswan',
#  'makushino',
#  'malpe',
#  'finnsnes',
#  'norman wells',
#  'mackay',
#  'aanekoski',
#  'calabozo',
#  'rio cuarto',
#  'colares',
#  'ola',
#  'tanete',
#  'honningsvag',
#  'berlevag',
#  'cockburn town',
#  'yerbogachen',
#  'tarkwa',
#  'tabuk',
#  'dianopolis',
#  'verkhnevilyuysk',
#  'los llanos de aridane',
#  'henties bay',
#  'gorontalo',
#  'sicamous',
#  'batemans bay',
#  'yuryevets',
#  'tarakan',
#  'yuxia',
#  'san ignacio',
#  'chulym',
#  'yelanskiy',
#  'emmaus',
#  'meulaboh',
#  'auki',
#  'kysyl-syr',
#  'goulburn',
#  'port jervis',
#  'boa vista',
#  'hinton',
#  'baracoa',
#  'afsin',
#  'tucuman',
#  'kalemie',
#  'utiroa',
#  'yambio',
#  'pimenta bueno',
#  'hedaru',
#  'wagga wagga',
#  'magadi',
#  'amga',
#  'vryburg',
#  'maniitsoq',
#  'tual',
#  'sabha',
#  'bambous virieux',
#  'atasu',
#  'mitha tiwana',
#  'saint-augustin',
#  'rivne',
#  'bialystok',
#  'xinmin',
#  'bara',
#  'homer',
#  'dmytrivka',
#  'ceres',
#  'fukue',
#  'kamaishi',
#  'yishui',
#  'hofn',
#  'timaru',
#  'kaduna',
#  'altus',
#  'dalaba',
#  'bagdarin',
#  'alamosa',
#  'norfolk',
#  'lakes entrance',
#  'thinadhoo',
#  'oktyabrskoye',
#  'yar-sale',
#  'khanpur',
#  'brekstad',
#  'coihaique',
#  'gardan diwal',
#  'batticaloa',
#  'port arthur',
#  'waingapu',
#  'yerofey pavlovich',
#  'pedasi',
#  'quang ngai',
#  'sri aman',
#  'wa',
#  'kawalu',
#  'bay roberts',
#  'varna',
#  'haapiti',
#  'camacupa',
#  'grand-santi',
#  'karpathos',
#  'escanaba',
#  'lubango',
#  'somerset west',
#  'gorno-chuyskiy',
#  'atambua',
#  'valle de allende',
#  'chau doc',
#  'ossora',
#  'vesyegonsk',
#  'carros',
#  'okha',
#  'tynda',
#  'xinzhi',
#  'klichka',
#  'kerchevskiy',
#  'miyako',
#  'heze',
#  'bogoslovka',
#  'seymchan',
#  'mujiayingzi',
#  'batagay-alyta',
#  'conceicao da barra',
#  'samarai',
#  'algiers',
#  'honolulu',
#  'salaga',
#  'lancaster',
#  'koslan',
#  'karoi',
#  'vauvert',
#  'charters towers',
#  'nangavalli',
#  'cap-haitien',
#  'kloulklubed',
#  'pachino',
#  'lavagna',
#  'jaen',
#  'peking',
#  'machiques',
#  'portland',
#  'ust-barguzin',
#  'muisne',
#  'sinnamary',
#  'skjervoy',
#  'porto velho',
#  'san martin',
#  'milingimbi',
#  'george town',
#  'shirvan',
#  'dawei',
#  'macapa',
#  'rafai',
#  'gloversville',
#  'aykhal']

# %% [markdown]
# #### Perform an API call with the OpenWeatherMap.

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6813e6d533615538ee19fa8e187979b

# %% [markdown]
# #### Retrieve the following information from the API call:
# - Latitude and longitude
# - Maximum temperature
# - Percent humidity
# - Percent cloudiness
# - Wind speed
# - Weather description (for example, clouds, fog, light rain, clear sky)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1



# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
     
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description})

                                  
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | saskylakh
# Processing Record 3 of Set 1 | avera
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | dikson
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | tuktoyaktuk
# Processing Record 8 of Set 1 | port elizabeth
# Processing Record 9 of Set 1 | whitehorse
# Processing Record 10 of Set 1 | college
# Processing Record 11 of Set 1 | fujishiro
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | waipawa
# Processing Record 14 of Set 1 | puerto del rosario
# Processing Record 15 of Set 1 | libacao
# Processing Record 16 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 1 | nouadhibou
# Processing Record 18 of Set 1 | craig
# Processing Record 19 of Set 1 | havre-saint-pierre
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | vardo
# Processing Record 22 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 1 | tsuruga
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | dahuk
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | hobart
# Processing Record 28 of Set 1 | maneadero
# Processing Record 29 of Set 1 | leningradskiy
# Processing Record 30 of Set 1 | ilulissat
# Processing Record 31 of Set 1 | sooke
# Processing Record 32 of Set 1 | provideniya
# Processing Record 33 of Set 1 | makakilo city
# Processing Record 34 of Set 1 | westport
# Processing Record 35 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 1 | kieta
# Processing Record 37 of Set 1 | ustye
# Processing Record 38 of Set 1 | jalu
# Processing Record 39 of Set 1 | tabou
# Processing Record 40 of Set 1 | severo-kurilsk
# Processing Record 41 of Set 1 | amapa
# Processing Record 42 of Set 1 | cidreira
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 1 | hilo
# Processing Record 46 of Set 1 | kaitangata
# Processing Record 47 of Set 1 | staryy nadym
# Processing Record 48 of Set 1 | alice springs
# Processing Record 49 of Set 1 | vaini
# Processing Record 50 of Set 1 | olinda
# Processing Record 1 of Set 2 | tuatapere
# Processing Record 2 of Set 2 | yellowknife
# Processing Record 3 of Set 2 | khorramabad
# Processing Record 4 of Set 2 | hermanus
# Processing Record 5 of Set 2 | thompson
# Processing Record 6 of Set 2 | mahibadhoo
# Processing Record 7 of Set 2 | arraial do cabo
# Processing Record 8 of Set 2 | maragogi
# Processing Record 9 of Set 2 | kapaa
# Processing Record 10 of Set 2 | lebu
# Processing Record 11 of Set 2 | iwaki
# Processing Record 12 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 2 | hovd
# Processing Record 14 of Set 2 | belle fourche
# Processing Record 15 of Set 2 | tokur
# Processing Record 16 of Set 2 | el tigre
# Processing Record 17 of Set 2 | panguna
# Processing Record 18 of Set 2 | barrow
# Processing Record 19 of Set 2 | atuona
# Processing Record 20 of Set 2 | ljungby
# Processing Record 21 of Set 2 | masvingo
# Processing Record 22 of Set 2 | touros
# Processing Record 23 of Set 2 | cayenne
# Processing Record 24 of Set 2 | ouesso
# Processing Record 25 of Set 2 | arlit
# Processing Record 26 of Set 2 | bintulu
# Processing Record 27 of Set 2 | puerto ayora
# Processing Record 28 of Set 2 | dickinson
# Processing Record 29 of Set 2 | coronel mariduena
# City not found. Skipping...
# Processing Record 30 of Set 2 | stornoway
# Processing Record 31 of Set 2 | atar
# Processing Record 32 of Set 2 | georgetown
# Processing Record 33 of Set 2 | anuradhapura
# Processing Record 34 of Set 2 | skagastrond
# City not found. Skipping...
# Processing Record 35 of Set 2 | ushuaia
# Processing Record 36 of Set 2 | caconda
# Processing Record 37 of Set 2 | sept-iles
# Processing Record 38 of Set 2 | butaritari
# Processing Record 39 of Set 2 | lamar
# Processing Record 40 of Set 2 | japura
# Processing Record 41 of Set 2 | hunza
# City not found. Skipping...
# Processing Record 42 of Set 2 | alofi
# Processing Record 43 of Set 2 | malaya serdoba
# Processing Record 44 of Set 2 | skibbereen
# Processing Record 45 of Set 2 | lazaro cardenas
# Processing Record 46 of Set 2 | nikolskoye
# Processing Record 47 of Set 2 | bluff
# Processing Record 48 of Set 2 | carbonia
# Processing Record 49 of Set 2 | synya
# Processing Record 50 of Set 2 | ratnagiri
# Processing Record 1 of Set 3 | nagua
# Processing Record 2 of Set 3 | biak
# Processing Record 3 of Set 3 | castro
# Processing Record 4 of Set 3 | lata
# Processing Record 5 of Set 3 | otane
# Processing Record 6 of Set 3 | zhigansk
# Processing Record 7 of Set 3 | monterey
# Processing Record 8 of Set 3 | lavrentiya
# Processing Record 9 of Set 3 | qaanaaq
# Processing Record 10 of Set 3 | kodiak
# Processing Record 11 of Set 3 | casino
# Processing Record 12 of Set 3 | half moon bay
# Processing Record 13 of Set 3 | ponta do sol
# Processing Record 14 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 3 | saint george
# Processing Record 16 of Set 3 | kijabe
# Processing Record 17 of Set 3 | sabang
# Processing Record 18 of Set 3 | san rafael
# Processing Record 19 of Set 3 | grindavik
# Processing Record 20 of Set 3 | bandarbeyla
# Processing Record 21 of Set 3 | caravelas
# Processing Record 22 of Set 3 | upernavik
# Processing Record 23 of Set 3 | san-pedro
# Processing Record 24 of Set 3 | black river
# Processing Record 25 of Set 3 | puerto escondido
# Processing Record 26 of Set 3 | chokurdakh
# Processing Record 27 of Set 3 | laguna
# Processing Record 28 of Set 3 | nanortalik
# Processing Record 29 of Set 3 | lamu
# Processing Record 30 of Set 3 | tres arroyos
# Processing Record 31 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 3 | tiksi
# Processing Record 33 of Set 3 | tommot
# Processing Record 34 of Set 3 | belmonte
# Processing Record 35 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 3 | muros
# Processing Record 37 of Set 3 | lircay
# Processing Record 38 of Set 3 | tabalosos
# Processing Record 39 of Set 3 | husavik
# Processing Record 40 of Set 3 | san quintin
# Processing Record 41 of Set 3 | sayat
# Processing Record 42 of Set 3 | mar del plata
# Processing Record 43 of Set 3 | cabo san lucas
# Processing Record 44 of Set 3 | tasiilaq
# Processing Record 45 of Set 3 | zemetchino
# Processing Record 46 of Set 3 | bredasdorp
# Processing Record 47 of Set 3 | zhoucheng
# Processing Record 48 of Set 3 | bulgan
# Processing Record 49 of Set 3 | sindor
# Processing Record 50 of Set 3 | esperance
# Processing Record 1 of Set 4 | katherine
# Processing Record 2 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 4 | busembatia
# Processing Record 4 of Set 4 | rumuruti
# Processing Record 5 of Set 4 | ust-omchug
# Processing Record 6 of Set 4 | grand-lahou
# Processing Record 7 of Set 4 | bontang
# Processing Record 8 of Set 4 | seoul
# Processing Record 9 of Set 4 | hithadhoo
# Processing Record 10 of Set 4 | roma
# Processing Record 11 of Set 4 | pacific grove
# Processing Record 12 of Set 4 | taseyevo
# Processing Record 13 of Set 4 | saint-philippe
# Processing Record 14 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 4 | hirado
# Processing Record 16 of Set 4 | prince rupert
# Processing Record 17 of Set 4 | saint-joseph
# Processing Record 18 of Set 4 | emba
# Processing Record 19 of Set 4 | kaeo
# Processing Record 20 of Set 4 | mitu
# Processing Record 21 of Set 4 | new norfolk
# Processing Record 22 of Set 4 | mangai
# Processing Record 23 of Set 4 | faanui
# Processing Record 24 of Set 4 | roswell
# Processing Record 25 of Set 4 | turukhansk
# Processing Record 26 of Set 4 | bhimunipatnam
# Processing Record 27 of Set 4 | pisco
# Processing Record 28 of Set 4 | ishigaki
# Processing Record 29 of Set 4 | iqaluit
# Processing Record 30 of Set 4 | mezofalva
# Processing Record 31 of Set 4 | bubaque
# Processing Record 32 of Set 4 | souillac
# Processing Record 33 of Set 4 | bengkulu
# Processing Record 34 of Set 4 | imamoglu
# Processing Record 35 of Set 4 | linxia
# Processing Record 36 of Set 4 | moron
# Processing Record 37 of Set 4 | gigmoto
# Processing Record 38 of Set 4 | kavaratti
# Processing Record 39 of Set 4 | lake havasu city
# Processing Record 40 of Set 4 | igarka
# Processing Record 41 of Set 4 | eston
# Processing Record 42 of Set 4 | udachnyy
# Processing Record 43 of Set 4 | yulara
# Processing Record 44 of Set 4 | bisho
# Processing Record 45 of Set 4 | guerrero negro
# Processing Record 46 of Set 4 | nome
# Processing Record 47 of Set 4 | cherskiy
# Processing Record 48 of Set 4 | san cristobal
# Processing Record 49 of Set 4 | terme
# Processing Record 50 of Set 4 | tinskoy
# Processing Record 1 of Set 5 | cururupu
# Processing Record 2 of Set 5 | les cayes
# Processing Record 3 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 5 | bang mun nak
# Processing Record 5 of Set 5 | hit
# Processing Record 6 of Set 5 | cruz alta
# Processing Record 7 of Set 5 | nijmegen
# Processing Record 8 of Set 5 | broome
# Processing Record 9 of Set 5 | fairbanks
# Processing Record 10 of Set 5 | chipinge
# Processing Record 11 of Set 5 | sungairaya
# Processing Record 12 of Set 5 | luoyang
# Processing Record 13 of Set 5 | ostrovnoy
# Processing Record 14 of Set 5 | mineiros
# Processing Record 15 of Set 5 | mizdah
# Processing Record 16 of Set 5 | adrar
# Processing Record 17 of Set 5 | ambilobe
# Processing Record 18 of Set 5 | san nicolas
# Processing Record 19 of Set 5 | bethel
# Processing Record 20 of Set 5 | quatre cocos
# Processing Record 21 of Set 5 | khatanga
# Processing Record 22 of Set 5 | afmadu
# City not found. Skipping...
# Processing Record 23 of Set 5 | belyy yar
# Processing Record 24 of Set 5 | lower hutt
# Processing Record 25 of Set 5 | turan
# Processing Record 26 of Set 5 | christchurch
# Processing Record 27 of Set 5 | ostersund
# Processing Record 28 of Set 5 | tamasane
# Processing Record 29 of Set 5 | mabaruma
# Processing Record 30 of Set 5 | marrakesh
# Processing Record 31 of Set 5 | sitka
# Processing Record 32 of Set 5 | codrington
# Processing Record 33 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 5 | riyadh
# Processing Record 35 of Set 5 | adra
# Processing Record 36 of Set 5 | salinopolis
# Processing Record 37 of Set 5 | faya
# Processing Record 38 of Set 5 | mount gambier
# Processing Record 39 of Set 5 | shadrinsk
# Processing Record 40 of Set 5 | aleksandrov gay
# Processing Record 41 of Set 5 | mouila
# Processing Record 42 of Set 5 | pundaguitan
# Processing Record 43 of Set 5 | gouyave
# Processing Record 44 of Set 5 | sahrak
# City not found. Skipping...
# Processing Record 45 of Set 5 | vaitape
# Processing Record 46 of Set 5 | chabahar
# Processing Record 47 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 5 | santiago del estero
# Processing Record 49 of Set 5 | angoche
# Processing Record 50 of Set 5 | hualmay
# Processing Record 1 of Set 6 | san carlos de bariloche
# Processing Record 2 of Set 6 | chuy
# Processing Record 3 of Set 6 | buala
# Processing Record 4 of Set 6 | hammerfest
# Processing Record 5 of Set 6 | broken hill
# Processing Record 6 of Set 6 | kahului
# Processing Record 7 of Set 6 | sao joao da barra
# Processing Record 8 of Set 6 | talcahuano
# Processing Record 9 of Set 6 | santiago
# Processing Record 10 of Set 6 | ahipara
# Processing Record 11 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 6 | sinjai
# Processing Record 13 of Set 6 | padang
# Processing Record 14 of Set 6 | labuhan
# Processing Record 15 of Set 6 | ribeira grande
# Processing Record 16 of Set 6 | avarua
# Processing Record 17 of Set 6 | rudnaya pristan
# Processing Record 18 of Set 6 | torbay
# Processing Record 19 of Set 6 | klaksvik
# Processing Record 20 of Set 6 | lompoc
# Processing Record 21 of Set 6 | komsomolskiy
# Processing Record 22 of Set 6 | kruisfontein
# Processing Record 23 of Set 6 | the valley
# Processing Record 24 of Set 6 | inhambane
# Processing Record 25 of Set 6 | mount isa
# Processing Record 26 of Set 6 | chokwe
# Processing Record 27 of Set 6 | wanaka
# Processing Record 28 of Set 6 | cap malheureux
# Processing Record 29 of Set 6 | taoudenni
# Processing Record 30 of Set 6 | camacha
# Processing Record 31 of Set 6 | werda
# Processing Record 32 of Set 6 | thunder bay
# Processing Record 33 of Set 6 | east london
# Processing Record 34 of Set 6 | ushtobe
# Processing Record 35 of Set 6 | saldanha
# Processing Record 36 of Set 6 | sarankhola
# Processing Record 37 of Set 6 | venice
# Processing Record 38 of Set 6 | byron bay
# Processing Record 39 of Set 6 | airai
# Processing Record 40 of Set 6 | harper
# Processing Record 41 of Set 6 | yumen
# Processing Record 42 of Set 6 | vila velha
# Processing Record 43 of Set 6 | calabar
# Processing Record 44 of Set 6 | luderitz
# Processing Record 45 of Set 6 | santa catarina de tepehuanes
# Processing Record 46 of Set 6 | chatellerault
# Processing Record 47 of Set 6 | savannakhet
# Processing Record 48 of Set 6 | vestmannaeyjar
# Processing Record 49 of Set 6 | ust-nera
# Processing Record 50 of Set 6 | bereda
# Processing Record 1 of Set 7 | shingu
# Processing Record 2 of Set 7 | olafsvik
# Processing Record 3 of Set 7 | lagoa
# Processing Record 4 of Set 7 | moree
# Processing Record 5 of Set 7 | staraya mayna
# Processing Record 6 of Set 7 | hobyo
# Processing Record 7 of Set 7 | suez
# Processing Record 8 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 7 | narsaq
# Processing Record 10 of Set 7 | borama
# City not found. Skipping...
# Processing Record 11 of Set 7 | sao filipe
# Processing Record 12 of Set 7 | port hardy
# Processing Record 13 of Set 7 | mugumu
# Processing Record 14 of Set 7 | dunedin
# Processing Record 15 of Set 7 | makurdi
# Processing Record 16 of Set 7 | sayyan
# Processing Record 17 of Set 7 | ancud
# Processing Record 18 of Set 7 | san juan
# Processing Record 19 of Set 7 | sembe
# Processing Record 20 of Set 7 | cartagena del chaira
# Processing Record 21 of Set 7 | ixtapa
# Processing Record 22 of Set 7 | manggar
# Processing Record 23 of Set 7 | karasjok
# Processing Record 24 of Set 7 | sakakah
# Processing Record 25 of Set 7 | shimoda
# Processing Record 26 of Set 7 | aldan
# Processing Record 27 of Set 7 | telford
# Processing Record 28 of Set 7 | boende
# Processing Record 29 of Set 7 | aden
# Processing Record 30 of Set 7 | carnarvon
# Processing Record 31 of Set 7 | belaya gora
# Processing Record 32 of Set 7 | korla
# Processing Record 33 of Set 7 | zanjan
# Processing Record 34 of Set 7 | dabat
# Processing Record 35 of Set 7 | tautira
# Processing Record 36 of Set 7 | cam ranh
# Processing Record 37 of Set 7 | victoria
# Processing Record 38 of Set 7 | mogadishu
# Processing Record 39 of Set 7 | kang
# Processing Record 40 of Set 7 | saint-louis
# Processing Record 41 of Set 7 | wilkie
# Processing Record 42 of Set 7 | muroto
# Processing Record 43 of Set 7 | kenora
# Processing Record 44 of Set 7 | masallatah
# Processing Record 45 of Set 7 | tabory
# Processing Record 46 of Set 7 | sola
# Processing Record 47 of Set 7 | geraldton
# Processing Record 48 of Set 7 | qinhuangdao
# Processing Record 49 of Set 7 | teknaf
# Processing Record 50 of Set 7 | clovis
# Processing Record 1 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 8 | frutal
# Processing Record 3 of Set 8 | acarau
# Processing Record 4 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 5 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 8 | segou
# Processing Record 7 of Set 8 | vysotsk
# Processing Record 8 of Set 8 | rocky mountain house
# Processing Record 9 of Set 8 | bairiki
# Processing Record 10 of Set 8 | lethem
# Processing Record 11 of Set 8 | asfi
# Processing Record 12 of Set 8 | gongzhuling
# Processing Record 13 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 14 of Set 8 | libertador general san martin
# Processing Record 15 of Set 8 | livingston
# Processing Record 16 of Set 8 | garissa
# Processing Record 17 of Set 8 | constitucion
# Processing Record 18 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 19 of Set 8 | graaff-reinet
# Processing Record 20 of Set 8 | russell
# Processing Record 21 of Set 8 | cleethorpes
# Processing Record 22 of Set 8 | centralia
# Processing Record 23 of Set 8 | coquimbo
# Processing Record 24 of Set 8 | mopipi
# Processing Record 25 of Set 8 | cairns
# Processing Record 26 of Set 8 | xichang
# Processing Record 27 of Set 8 | mayo
# Processing Record 28 of Set 8 | akyab
# Processing Record 29 of Set 8 | agropoli
# Processing Record 30 of Set 8 | rocha
# Processing Record 31 of Set 8 | talisayan
# Processing Record 32 of Set 8 | klimovo
# Processing Record 33 of Set 8 | monrovia
# Processing Record 34 of Set 8 | kaniama
# Processing Record 35 of Set 8 | moose factory
# Processing Record 36 of Set 8 | fort dodge
# Processing Record 37 of Set 8 | pevek
# Processing Record 38 of Set 8 | uglegorsk
# Processing Record 39 of Set 8 | lorengau
# Processing Record 40 of Set 8 | dali
# Processing Record 41 of Set 8 | nelson bay
# Processing Record 42 of Set 8 | port lincoln
# Processing Record 43 of Set 8 | sorland
# Processing Record 44 of Set 8 | port moresby
# Processing Record 45 of Set 8 | katsuura
# Processing Record 46 of Set 8 | athens
# Processing Record 47 of Set 8 | burica
# City not found. Skipping...
# Processing Record 48 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 49 of Set 8 | mehamn
# Processing Record 50 of Set 8 | oranmore
# Processing Record 1 of Set 9 | kurilsk
# Processing Record 2 of Set 9 | deputatskiy
# Processing Record 3 of Set 9 | banmo
# City not found. Skipping...
# Processing Record 4 of Set 9 | itarema
# Processing Record 5 of Set 9 | neiafu
# Processing Record 6 of Set 9 | dawson creek
# Processing Record 7 of Set 9 | arraias
# Processing Record 8 of Set 9 | chiredzi
# Processing Record 9 of Set 9 | hamilton
# Processing Record 10 of Set 9 | longyearbyen
# Processing Record 11 of Set 9 | gravelbourg
# Processing Record 12 of Set 9 | le mans
# Processing Record 13 of Set 9 | starobaltachevo
# Processing Record 14 of Set 9 | katangli
# Processing Record 15 of Set 9 | port said
# Processing Record 16 of Set 9 | lasa
# Processing Record 17 of Set 9 | goderich
# Processing Record 18 of Set 9 | qianjiang
# Processing Record 19 of Set 9 | elmira
# Processing Record 20 of Set 9 | hendek
# Processing Record 21 of Set 9 | quelimane
# Processing Record 22 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 23 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 24 of Set 9 | lebanon
# Processing Record 25 of Set 9 | warmbad
# Processing Record 26 of Set 9 | wuwei
# Processing Record 27 of Set 9 | lima
# Processing Record 28 of Set 9 | luwuk
# Processing Record 29 of Set 9 | totma
# Processing Record 30 of Set 9 | kasongo-lunda
# Processing Record 31 of Set 9 | keti bandar
# Processing Record 32 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 9 | sartell
# Processing Record 34 of Set 9 | kiunga
# Processing Record 35 of Set 9 | namibe
# Processing Record 36 of Set 9 | atakpame
# Processing Record 37 of Set 9 | mahebourg
# Processing Record 38 of Set 9 | vostok
# Processing Record 39 of Set 9 | charlestown
# Processing Record 40 of Set 9 | kushima
# Processing Record 41 of Set 9 | taltal
# Processing Record 42 of Set 9 | loa janan
# Processing Record 43 of Set 9 | qasigiannguit
# Processing Record 44 of Set 9 | cojumatlan
# City not found. Skipping...
# Processing Record 45 of Set 9 | kutum
# Processing Record 46 of Set 9 | tigre
# Processing Record 47 of Set 9 | necochea
# Processing Record 48 of Set 9 | bukoba
# Processing Record 49 of Set 9 | saint-pierre
# Processing Record 50 of Set 9 | teluknaga
# Processing Record 1 of Set 10 | haines junction
# Processing Record 2 of Set 10 | nuuk
# Processing Record 3 of Set 10 | urumqi
# Processing Record 4 of Set 10 | cottbus
# Processing Record 5 of Set 10 | korgen
# Processing Record 6 of Set 10 | sobolevo
# Processing Record 7 of Set 10 | zyryanka
# Processing Record 8 of Set 10 | langres
# Processing Record 9 of Set 10 | bumbuna
# Processing Record 10 of Set 10 | port blair
# Processing Record 11 of Set 10 | dingle
# Processing Record 12 of Set 10 | ternate
# Processing Record 13 of Set 10 | mitsamiouli
# Processing Record 14 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 10 | sochi
# Processing Record 16 of Set 10 | puerto leguizamo
# Processing Record 17 of Set 10 | sechura
# Processing Record 18 of Set 10 | houma
# Processing Record 19 of Set 10 | svirstroy
# Processing Record 20 of Set 10 | flinders
# Processing Record 21 of Set 10 | porto novo
# Processing Record 22 of Set 10 | skelleftea
# Processing Record 23 of Set 10 | pahrump
# Processing Record 24 of Set 10 | bambari
# Processing Record 25 of Set 10 | nara
# Processing Record 26 of Set 10 | muravlenko
# Processing Record 27 of Set 10 | inuvik
# Processing Record 28 of Set 10 | pemangkat
# Processing Record 29 of Set 10 | tamale
# Processing Record 30 of Set 10 | sechenovo
# Processing Record 31 of Set 10 | atbasar
# Processing Record 32 of Set 10 | cosala
# Processing Record 33 of Set 10 | jawa
# Processing Record 34 of Set 10 | ucluelet
# Processing Record 35 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 36 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 10 | rock sound
# Processing Record 38 of Set 10 | adre
# Processing Record 39 of Set 10 | sharan
# Processing Record 40 of Set 10 | huitzuco
# City not found. Skipping...
# Processing Record 41 of Set 10 | madimba
# Processing Record 42 of Set 10 | kabanjahe
# Processing Record 43 of Set 10 | phangnga
# Processing Record 44 of Set 10 | baruun-urt
# Processing Record 45 of Set 10 | cochrane
# Processing Record 46 of Set 10 | mananjary
# Processing Record 47 of Set 10 | englewood
# Processing Record 48 of Set 10 | salalah
# Processing Record 49 of Set 10 | tefe
# Processing Record 50 of Set 10 | nichinan
# Processing Record 1 of Set 11 | umm kaddadah
# Processing Record 2 of Set 11 | san patricio
# Processing Record 3 of Set 11 | chunoyar
# Processing Record 4 of Set 11 | santa rita
# Processing Record 5 of Set 11 | prabumulih
# Processing Record 6 of Set 11 | nemuro
# Processing Record 7 of Set 11 | hoquiam
# Processing Record 8 of Set 11 | letka
# Processing Record 9 of Set 11 | puliyankudi
# Processing Record 10 of Set 11 | venado tuerto
# Processing Record 11 of Set 11 | tibiri
# Processing Record 12 of Set 11 | kashi
# Processing Record 13 of Set 11 | motygino
# Processing Record 14 of Set 11 | mana
# Processing Record 15 of Set 11 | aneho
# Processing Record 16 of Set 11 | pangkalanbuun
# Processing Record 17 of Set 11 | hami
# Processing Record 18 of Set 11 | kamloops
# Processing Record 19 of Set 11 | innisfail
# Processing Record 20 of Set 11 | marawi
# Processing Record 21 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 11 | namatanai
# Processing Record 23 of Set 11 | gidam
# Processing Record 24 of Set 11 | kankon
# Processing Record 25 of Set 11 | marzuq
# Processing Record 26 of Set 11 | santa lucia
# Processing Record 27 of Set 11 | gopalganj
# Processing Record 28 of Set 11 | morros
# Processing Record 29 of Set 11 | khani
# Processing Record 30 of Set 11 | praia
# Processing Record 31 of Set 11 | sungaipenuh
# Processing Record 32 of Set 11 | isangel
# Processing Record 33 of Set 11 | candawaga
# City not found. Skipping...
# Processing Record 34 of Set 11 | manyana
# Processing Record 35 of Set 11 | ginda
# Processing Record 36 of Set 11 | abhar
# Processing Record 37 of Set 11 | raduzhnyy
# Processing Record 38 of Set 11 | bolonchen
# City not found. Skipping...
# Processing Record 39 of Set 11 | simplicio mendes
# Processing Record 40 of Set 11 | asmar
# Processing Record 41 of Set 11 | champerico
# Processing Record 42 of Set 11 | san felipe
# Processing Record 43 of Set 11 | kavieng
# Processing Record 44 of Set 11 | beni mazar
# Processing Record 45 of Set 11 | beira
# Processing Record 46 of Set 11 | ondjiva
# Processing Record 47 of Set 11 | bulaevo
# Processing Record 48 of Set 11 | salair
# Processing Record 49 of Set 11 | larsnes
# Processing Record 50 of Set 11 | zabol
# Processing Record 1 of Set 12 | trairi
# Processing Record 2 of Set 12 | kamennomostskiy
# Processing Record 3 of Set 12 | springville
# Processing Record 4 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 5 of Set 12 | siva
# Processing Record 6 of Set 12 | machico
# Processing Record 7 of Set 12 | lipari
# Processing Record 8 of Set 12 | wattegama
# Processing Record 9 of Set 12 | chernyakhiv
# Processing Record 10 of Set 12 | grand gaube
# Processing Record 11 of Set 12 | boyolangu
# Processing Record 12 of Set 12 | mastic beach
# Processing Record 13 of Set 12 | gurgan
# City not found. Skipping...
# Processing Record 14 of Set 12 | marks
# Processing Record 15 of Set 12 | odweyne
# Processing Record 16 of Set 12 | aklavik
# Processing Record 17 of Set 12 | hope
# Processing Record 18 of Set 12 | kiama
# Processing Record 19 of Set 12 | huntsville
# Processing Record 20 of Set 12 | ulladulla
# Processing Record 21 of Set 12 | asau
# Processing Record 22 of Set 12 | sao miguel do araguaia
# Processing Record 23 of Set 12 | mirnyy
# Processing Record 24 of Set 12 | los banos
# Processing Record 25 of Set 12 | ulaangom
# Processing Record 26 of Set 12 | oranjemund
# Processing Record 27 of Set 12 | pangnirtung
# Processing Record 28 of Set 12 | le port
# Processing Record 29 of Set 12 | pyaozerskiy
# Processing Record 30 of Set 12 | sena madureira
# Processing Record 31 of Set 12 | martil
# Processing Record 32 of Set 12 | dzhida
# Processing Record 33 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 34 of Set 12 | clyde river
# Processing Record 35 of Set 12 | tamandare
# Processing Record 36 of Set 12 | ercis
# Processing Record 37 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 38 of Set 12 | poum
# Processing Record 39 of Set 12 | tilichiki
# Processing Record 40 of Set 12 | yining
# Processing Record 41 of Set 12 | nakamura
# Processing Record 42 of Set 12 | sao francisco
# Processing Record 43 of Set 12 | egvekinot
# Processing Record 44 of Set 12 | dukat
# Processing Record 45 of Set 12 | tagusao
# Processing Record 46 of Set 12 | moengo
# Processing Record 47 of Set 12 | sao felix do xingu
# Processing Record 48 of Set 12 | lerwick
# Processing Record 49 of Set 12 | bonthe
# Processing Record 50 of Set 12 | raton
# Processing Record 1 of Set 13 | senmonorom
# City not found. Skipping...
# Processing Record 2 of Set 13 | vao
# Processing Record 3 of Set 13 | batesville
# Processing Record 4 of Set 13 | wajir
# Processing Record 5 of Set 13 | miraflores
# Processing Record 6 of Set 13 | hasaki
# Processing Record 7 of Set 13 | talnakh
# Processing Record 8 of Set 13 | north bend
# Processing Record 9 of Set 13 | qaqortoq
# Processing Record 10 of Set 13 | manta
# Processing Record 11 of Set 13 | khilok
# Processing Record 12 of Set 13 | tabukiniberu
# City not found. Skipping...
# Processing Record 13 of Set 13 | myitkyina
# Processing Record 14 of Set 13 | rio gallegos
# Processing Record 15 of Set 13 | serrinha
# Processing Record 16 of Set 13 | tawzar
# City not found. Skipping...
# Processing Record 17 of Set 13 | verkhnyaya inta
# Processing Record 18 of Set 13 | santa rosa
# Processing Record 19 of Set 13 | sigli
# Processing Record 20 of Set 13 | ritchie
# Processing Record 21 of Set 13 | vanimo
# Processing Record 22 of Set 13 | castelo branco
# Processing Record 23 of Set 13 | moranbah
# Processing Record 24 of Set 13 | palmer
# Processing Record 25 of Set 13 | plettenberg bay
# Processing Record 26 of Set 13 | suruc
# Processing Record 27 of Set 13 | vilhena
# Processing Record 28 of Set 13 | maceio
# Processing Record 29 of Set 13 | aswan
# Processing Record 30 of Set 13 | makushino
# Processing Record 31 of Set 13 | malpe
# Processing Record 32 of Set 13 | finnsnes
# Processing Record 33 of Set 13 | norman wells
# Processing Record 34 of Set 13 | mackay
# Processing Record 35 of Set 13 | aanekoski
# Processing Record 36 of Set 13 | calabozo
# Processing Record 37 of Set 13 | rio cuarto
# Processing Record 38 of Set 13 | colares
# Processing Record 39 of Set 13 | ola
# Processing Record 40 of Set 13 | tanete
# Processing Record 41 of Set 13 | honningsvag
# Processing Record 42 of Set 13 | berlevag
# Processing Record 43 of Set 13 | cockburn town
# Processing Record 44 of Set 13 | yerbogachen
# Processing Record 45 of Set 13 | tarkwa
# Processing Record 46 of Set 13 | tabuk
# Processing Record 47 of Set 13 | dianopolis
# City not found. Skipping...
# Processing Record 48 of Set 13 | verkhnevilyuysk
# Processing Record 49 of Set 13 | los llanos de aridane
# Processing Record 50 of Set 13 | henties bay
# Processing Record 1 of Set 14 | gorontalo
# Processing Record 2 of Set 14 | sicamous
# Processing Record 3 of Set 14 | batemans bay
# Processing Record 4 of Set 14 | yuryevets
# Processing Record 5 of Set 14 | tarakan
# Processing Record 6 of Set 14 | yuxia
# Processing Record 7 of Set 14 | san ignacio
# Processing Record 8 of Set 14 | chulym
# Processing Record 9 of Set 14 | yelanskiy
# Processing Record 10 of Set 14 | emmaus
# Processing Record 11 of Set 14 | meulaboh
# Processing Record 12 of Set 14 | auki
# Processing Record 13 of Set 14 | kysyl-syr
# Processing Record 14 of Set 14 | goulburn
# Processing Record 15 of Set 14 | port jervis
# Processing Record 16 of Set 14 | boa vista
# Processing Record 17 of Set 14 | hinton
# Processing Record 18 of Set 14 | baracoa
# Processing Record 19 of Set 14 | afsin
# Processing Record 20 of Set 14 | tucuman
# Processing Record 21 of Set 14 | kalemie
# Processing Record 22 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 23 of Set 14 | yambio
# Processing Record 24 of Set 14 | pimenta bueno
# Processing Record 25 of Set 14 | hedaru
# Processing Record 26 of Set 14 | wagga wagga
# Processing Record 27 of Set 14 | magadi
# Processing Record 28 of Set 14 | amga
# Processing Record 29 of Set 14 | vryburg
# Processing Record 30 of Set 14 | maniitsoq
# Processing Record 31 of Set 14 | tual
# Processing Record 32 of Set 14 | sabha
# Processing Record 33 of Set 14 | bambous virieux
# Processing Record 34 of Set 14 | atasu
# Processing Record 35 of Set 14 | mitha tiwana
# Processing Record 36 of Set 14 | saint-augustin
# Processing Record 37 of Set 14 | rivne
# Processing Record 38 of Set 14 | bialystok
# Processing Record 39 of Set 14 | xinmin
# Processing Record 40 of Set 14 | bara
# Processing Record 41 of Set 14 | homer
# Processing Record 42 of Set 14 | dmytrivka
# Processing Record 43 of Set 14 | ceres
# Processing Record 44 of Set 14 | fukue
# Processing Record 45 of Set 14 | kamaishi
# Processing Record 46 of Set 14 | yishui
# Processing Record 47 of Set 14 | hofn
# Processing Record 48 of Set 14 | timaru
# Processing Record 49 of Set 14 | kaduna
# Processing Record 50 of Set 14 | altus
# Processing Record 1 of Set 15 | dalaba
# Processing Record 2 of Set 15 | bagdarin
# Processing Record 3 of Set 15 | alamosa
# Processing Record 4 of Set 15 | norfolk
# Processing Record 5 of Set 15 | lakes entrance
# Processing Record 6 of Set 15 | thinadhoo
# Processing Record 7 of Set 15 | oktyabrskoye
# Processing Record 8 of Set 15 | yar-sale
# Processing Record 9 of Set 15 | khanpur
# Processing Record 10 of Set 15 | brekstad
# Processing Record 11 of Set 15 | coihaique
# Processing Record 12 of Set 15 | gardan diwal
# City not found. Skipping...
# Processing Record 13 of Set 15 | batticaloa
# Processing Record 14 of Set 15 | port arthur
# Processing Record 15 of Set 15 | waingapu
# Processing Record 16 of Set 15 | yerofey pavlovich
# Processing Record 17 of Set 15 | pedasi
# Processing Record 18 of Set 15 | quang ngai
# Processing Record 19 of Set 15 | sri aman
# Processing Record 20 of Set 15 | wa
# City not found. Skipping...
# Processing Record 21 of Set 15 | kawalu
# Processing Record 22 of Set 15 | bay roberts
# Processing Record 23 of Set 15 | varna
# Processing Record 24 of Set 15 | haapiti
# Processing Record 25 of Set 15 | camacupa
# Processing Record 26 of Set 15 | grand-santi
# Processing Record 27 of Set 15 | karpathos
# Processing Record 28 of Set 15 | escanaba
# Processing Record 29 of Set 15 | lubango
# Processing Record 30 of Set 15 | somerset west
# Processing Record 31 of Set 15 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 32 of Set 15 | atambua
# Processing Record 33 of Set 15 | valle de allende
# Processing Record 34 of Set 15 | chau doc
# Processing Record 35 of Set 15 | ossora
# Processing Record 36 of Set 15 | vesyegonsk
# Processing Record 37 of Set 15 | carros
# Processing Record 38 of Set 15 | okha
# Processing Record 39 of Set 15 | tynda
# Processing Record 40 of Set 15 | xinzhi
# Processing Record 41 of Set 15 | klichka
# Processing Record 42 of Set 15 | kerchevskiy
# Processing Record 43 of Set 15 | miyako
# Processing Record 44 of Set 15 | heze
# Processing Record 45 of Set 15 | bogoslovka
# Processing Record 46 of Set 15 | seymchan
# Processing Record 47 of Set 15 | mujiayingzi
# Processing Record 48 of Set 15 | batagay-alyta
# Processing Record 49 of Set 15 | conceicao da barra
# Processing Record 50 of Set 15 | samarai
# Processing Record 1 of Set 16 | algiers
# Processing Record 2 of Set 16 | honolulu
# Processing Record 3 of Set 16 | salaga
# Processing Record 4 of Set 16 | lancaster
# Processing Record 5 of Set 16 | koslan
# Processing Record 6 of Set 16 | karoi
# Processing Record 7 of Set 16 | vauvert
# Processing Record 8 of Set 16 | charters towers
# Processing Record 9 of Set 16 | nangavalli
# Processing Record 10 of Set 16 | cap-haitien
# Processing Record 11 of Set 16 | kloulklubed
# Processing Record 12 of Set 16 | pachino
# Processing Record 13 of Set 16 | lavagna
# Processing Record 14 of Set 16 | jaen
# Processing Record 15 of Set 16 | peking
# Processing Record 16 of Set 16 | machiques
# Processing Record 17 of Set 16 | portland
# Processing Record 18 of Set 16 | ust-barguzin
# Processing Record 19 of Set 16 | muisne
# Processing Record 20 of Set 16 | sinnamary
# Processing Record 21 of Set 16 | skjervoy
# Processing Record 22 of Set 16 | porto velho
# Processing Record 23 of Set 16 | san martin
# Processing Record 24 of Set 16 | milingimbi
# City not found. Skipping...
# Processing Record 25 of Set 16 | george town
# Processing Record 26 of Set 16 | shirvan
# Processing Record 27 of Set 16 | dawei
# Processing Record 28 of Set 16 | macapa
# Processing Record 29 of Set 16 | rafai
# Processing Record 30 of Set 16 | gloversville
# Processing Record 31 of Set 16 | aykhal
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 728

# %% [markdown]
# #### Add the data to a new DataFrame.

# %%
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Rikitea      PF -23.1203 -134.9692     78.39        77          92
# 1  Saskylakh      RU  71.9167  114.0833    -26.19        83          77
# 2      Avera      US  33.1940  -82.5271     30.20        92           1
# 3    Mataura      NZ -46.1927  168.8643     52.00        94          79
# 4     Dikson      RU  73.5069   80.5464      2.08        94         100
#
#    Wind Speed      Description
# 0       13.69  overcast clouds
# 1        9.78    broken clouds
# 2        4.61             haze
# 3       14.00    broken clouds
# 4       19.66       light snow

# %% [markdown]
# #### Export the DataFrame as a CSV file

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
